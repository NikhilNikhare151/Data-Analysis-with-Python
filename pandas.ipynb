# %%
pip install cx_Oracle
# Out:
# ...
#   Using cached cx_Oracle-8.3.0.tar.gz (363 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
# Failed to build cx_Oracle
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
# ...
#   exit code: 1
#
#   [8 lines of output]
#   <string>:6: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   C:\Users\Akhil\AppData\Local\Temp\pip-build-env-833j54px\overlay\Lib\site-packages\setuptools\config\expand.py:124: SetuptoolsWarning: File 'C:\\Users\\Akhil\\AppData\\Local\\Temp\\pip-install-13zodxq9\\cx-oracle_fe130c31ace843409bd525e3468266df\\README.md' cannot be found
# ...

# %%
pip install oracledb
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
import numpy as np
import pandas as pd

# %%
s1=pd.Series([1,4,2,6,2,3,5])
s1
# Out:
# 0    1
# 1    4
# 2    2
# 3    6
# 4    2
# 5    3
# 6    5
# dtype: int64

# %%
s2=pd.Series(np.random.randint(1000,7000,10))
s2
# Out:
# 0    1025
# 1    2091
# 2    6491
# 3    6867
# 4    3344
# 5    5925
# 6    2089
# 7    3011
# 8    4853
# 9    4042
# dtype: int32

# %%
s3=pd.Series(["Ram", "Shyam", "Sita", "Gita"])
s3
# Out:
# 0      Ram
# 1    Shyam
# 2     Sita
# 3     Gita
# dtype: object

# %%
s3.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
s3.values
# Out:
# array(['Ram', 'Shyam', 'Sita', 'Gita'], dtype=object)

# %%
s4=pd.Series(["Sachin","Rohit","Virat","Hardik"],index=["MI-10","MI-45","RCB-18","GL-33"])
s4
# Out:
# MI-10     Sachin
# MI-45      Rohit
# RCB-18     Virat
# GL-33     Hardik
# dtype: object

# %%
s4.index
# Out:
# Index(['MI-10', 'MI-45', 'RCB-18', 'GL-33'], dtype='object')

# %%
s4.values
# Out:
# array(['Sachin', 'Rohit', 'Virat', 'Hardik'], dtype=object)

# %%
ls=[["Sachin",10,10345,560,"Munbai"],
    ["Rohit",45,8732,232,"Mumbai"],
    ["MS Dhoni",7,10048,350,"Rachi"],
    ["Virat",18,11842,328,"Delhi"]]

# %%
player=pd.DataFrame(ls)
player
# Out:
#           0   1      2    3       4
# 0    Sachin  10  10345  560  Munbai
# 1     Rohit  45   8732  232  Mumbai
# 2  MS Dhoni   7  10048  350   Rachi
# 3     Virat  18  11842  328   Delhi

# %%
player=pd.DataFrame(ls, columns=["Name","Jersy","Runs","Matches","City"])
player
# Out:
#        Name  Jersy   Runs  Matches    City
# 0    Sachin     10  10345      560  Munbai
# 1     Rohit     45   8732      232  Mumbai
# 2  MS Dhoni      7  10048      350   Rachi
# 3     Virat     18  11842      328   Delhi

# %%
std_per=pd.read_csv(r"C:\Users\Akhil\Desktop\data analytics\Student Performance.csv")
std_per
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
std_per=pd.read_csv("Student Performance.csv")
std_per
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
hr=pd.read_excel("HR Dataset.xlsx")
hr
# Out:
#           Employee_Name Married GenderID  Salary                  Position  \
# 0    Adinolfi Wilson  K      No     Male   62506   Production Technician I
# 1           AlagbeTrina     Yes   Female   64991   Production Technician I
# 2        Anderson Linda      No   Female   57568   Production Technician I
# 3            Athwal Sam      No     Male   59365   Production Technician I
# 4       Bachiochi Linda      No   Female   47837   Production Technician I
# ..                  ...     ...      ...     ...                       ...
# 306      Whittier Scott      No     Male   58371   Production Technician I
# 307        Wilber Barry     Yes     Male   55140   Production Technician I
# 308        Wilkes Annie      No   Female   58062   Production Technician I
# 309  Williams Jacquelyn      No   Female   59728   Production Technician I
# 310     Winthrop Jordan      No     Male   70507  Production Technician II
#
#     State   Zip Marital Status          CitizenDesc  \
# ...

# %%
population=pd.read_html("https://statisticstimes.com/demographics/india/indian-states-population.php")
population[1]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\compat\_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1126, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# ...

# %%
std_per.info
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 std_per.info
#
# NameError: name 'std_per' is not defined

# %%
std_per.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 std_per.describe()
#
# NameError: name 'std_per' is not defined

# %%
hr.desctibe()

# %%
hr["Salary"],describe()

# %%
std_per["gender"]

# %%
std_per["gender"].value_counts()

# %%
hr

# %%
hr[["Employee_Name","Married","GenderID"]]

# %%
hr.isna()

# %%
hr.isna().sum()

# %%
hr.duplicated()

# %%
hr.duplicated().sum()

# %%
std_per.tail(10)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 990    male        group E                 high school  free/reduced
# 991  female        group B            some high school      standard
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 994    male        group A                 high school      standard
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 990               completed          86             81             75
# ...

# %%
std_per.sample()
# Out:
#      gender race/ethnicity parental level of education     lunch  \
# 397  female        group C          associate's degree  standard
#
#     test preparation course  math score  reading score  writing score
# 397                    none          85             89             95

# %%
std_per.sample(5)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 187    male        group D            some high school      standard
# 497  female        group D                some college  free/reduced
# 416    male        group C           bachelor's degree      standard
# 825    male        group C                 high school      standard
# 652  female        group D                some college      standard
#
#     test preparation course  math score  reading score  writing score
# 187               completed          62             66             68
# 497               completed          59             78             76
# 416               completed          71             74             68
# 825                    none          62             67             58
# 652               completed          85             86             98

# %%
std_per.sample(10,random_state=25)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 688    male        group A                 high school  free/reduced
# 49     male        group C                 high school      standard
# 288    male        group B           bachelor's degree  free/reduced
# 698  female        group D          associate's degree      standard
# 775  female        group B            some high school  free/reduced
# 305    male        group A                some college      standard
# 279    male        group B           bachelor's degree  free/reduced
# 599  female        group D            some high school      standard
# 988  female        group A            some high school  free/reduced
# 627    male        group D          associate's degree      standard
#
#     test preparation course  math score  reading score  writing score
# 688                    none          53             58             44
# ...

# %%
std_per["gender"]
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
std_per
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
std_per[["gender","lunch","writing score"]]
# Out:
#      gender         lunch  writing score
# 0    female      standard             74
# 1    female      standard             88
# 2    female      standard             93
# 3      male  free/reduced             44
# 4      male      standard             75
# ..      ...           ...            ...
# 995  female      standard             95
# 996    male  free/reduced             55
# 997  female  free/reduced             65
# 998  female      standard             77
# 999  female  free/reduced             86
#
# [1000 rows x 3 columns]

# %%
std_per.iloc[356]
# Out:
# gender                                       male
# race/ethnicity                            group A
# parental level of education    associate's degree
# lunch                                    standard
# test preparation course                      none
# math score                                     63
# reading score                                  61
# writing score                                  61
# Name: 356, dtype: object

# %%
std_per.iloc[356:361]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 356    male        group A          associate's degree      standard
# 357  female        group C                some college  free/reduced
# 358    male        group D                some college  free/reduced
# 359  female        group D                some college      standard
# 360  female        group B                 high school      standard
#
#     test preparation course  math score  reading score  writing score
# 356                    none          63             61             61
# 357               completed          42             66             69
# 358                    none          59             62             61
# 359                    none          80             90             89
# 360                    none          58             62             59

# %%
std_per.iloc[356:391:4]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 356    male        group A          associate's degree      standard
# 360  female        group B                 high school      standard
# 364    male        group C                some college      standard
# 368  female        group A            some high school  free/reduced
# 372    male        group D            some high school      standard
# 376  female        group D            some high school      standard
# 380  female        group B          associate's degree      standard
# 384  female        group A            some high school  free/reduced
# 388  female        group D                 high school      standard
#
#     test preparation course  math score  reading score  writing score
# 356                    none          63             61             61
# 360                    none          58             62             59
# ...

# %%
std_per.iloc[86:94,1]
# Out:
# 86    group C
# 87    group D
# 88    group A
# 89    group D
# 90    group C
# 91    group C
# 92    group C
# 93    group C
# Name: race/ethnicity, dtype: object

# %%
std_per.iloc[86:94,3:6]
# Out:
#            lunch test preparation course  math score
# 86  free/reduced                    none          76
# 87      standard                    none          71
# 88      standard                    none          58
# 89      standard                    none          73
# 90      standard                    none          65
# 91  free/reduced                    none          27
# 92      standard                    none          71
# 93  free/reduced               completed          43

# %%
std_per.loc[234]
# Out:
# gender                                      male
# race/ethnicity                           group C
# parental level of education    bachelor's degree
# lunch                                   standard
# test preparation course                completed
# math score                                    83
# reading score                                 82
# writing score                                 84
# Name: 234, dtype: object

# %%
std_per.loc[86:94]
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 86  female        group C                some college  free/reduced
# 87  female        group D          associate's degree      standard
# 88  female        group A                some college      standard
# 89  female        group D            some high school      standard
# 90  female        group C           bachelor's degree      standard
# 91    male        group C                 high school  free/reduced
# 92    male        group C                 high school      standard
# 93    male        group C          associate's degree  free/reduced
# 94  female        group B                some college      standard
#
#    test preparation course  math score  reading score  writing score
# 86                    none          76             83             88
# 87                    none          71             71             74
# 88                    none          58             70             67
# ...

# %%
std_per.loc[86:94,["lunch","math score","reading score"]]
# Out:
#            lunch  math score  reading score
# 86  free/reduced          76             83
# 87      standard          71             71
# 88      standard          58             70
# 89      standard          73             86
# 90      standard          65             72
# 91  free/reduced          27             34
# 92      standard          71             79
# 93  free/reduced          43             45
# 94      standard          79             86

# %%
std_per.loc[86:94,"gender":"math score"]
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 86  female        group C                some college  free/reduced
# 87  female        group D          associate's degree      standard
# 88  female        group A                some college      standard
# 89  female        group D            some high school      standard
# 90  female        group C           bachelor's degree      standard
# 91    male        group C                 high school  free/reduced
# 92    male        group C                 high school      standard
# 93    male        group C          associate's degree  free/reduced
# 94  female        group B                some college      standard
#
#    test preparation course  math score
# 86                    none          76
# 87                    none          71
# 88                    none          58
# 89                    none          73
# 90                    none          65
# 91                    none          27
# ...

# %%
std_per["math score"].sum()
# Out:
# np.int64(66089)

# %%
std_per["math score"].mean()
# Out:
# np.float64(66.089)

# %%
std_per["math score"].std()
# Out:
# np.float64(15.16308009600945)

# %%
std_per["gender"].value_counts()
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64

# %%
std_per.groupby("gender")["math score"].mean()
# Out:
# gender
# female    63.633205
# male      68.728216
# Name: math score, dtype: float64

# %%
std_per.groupby("gender")["math score"].min()
# Out:
# gender
# female     0
# male      27
# Name: math score, dtype: int64

# %%
std_per.groupby("gender")["math score"].max()
# Out:
# gender
# female    100
# male      100
# Name: math score, dtype: int64

# %%
std_per.groupby("gender")["math score"].std()
# Out:
# gender
# female    15.491453
# male      14.356277
# Name: math score, dtype: float64

# %%
std_per.groupby(["race/ethnicity","gender"])[["math score","reading score","writing score"]].mean()
# Out:
#                        math score  reading score  writing score
# race/ethnicity gender
# group A        female   58.527778      69.000000      67.861111
#                male     63.735849      61.735849      59.150943
# group B        female   61.403846      71.076923      70.048077
#                male     65.930233      62.848837      60.220930
# group C        female   62.033333      71.944444      71.777778
#                male     67.611511      65.424460      62.712230
# group D        female   65.248062      74.046512      75.023256
#                male     69.413534      66.135338      65.413534
# group E        female   70.811594      75.840580      75.536232
#                male     76.746479      70.295775      67.394366

# %%
std_per
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
std_per.groupby(["race/ethnicity","gender","parental level of education"])[["math score","reading score","writing score"]].max()
# Out:
#                                                    math score  reading score  \
# race/ethnicity gender parental level of education
# group A        female associate's degree                   82             93
#                       bachelor's degree                    59             72
#                       high school                          77             88
#                       master's degree                      50             67
#                       some college                         78             87
#                       some high school                     92            100
#                male   associate's degree                   97             92
#                       bachelor's degree                    91             96
#                       high school                          72             74
#                       master's degree                      73             74
# ...

# %%
std_per.groupby(["race/ethnicity","gender","lunch"])[["math score","reading score","writing score"]].min()
# Out:
#                                     math score  reading score  writing score
# race/ethnicity gender lunch
# group A        female free/reduced          34             43             41
#                       standard              45             49             51
#                male   free/reduced          28             23             19
#                       standard              46             31             36
# group B        female free/reduced           8             24             23
#                       standard              19             38             32
#                male   free/reduced          30             24             15
#                       standard              47             42             41
# group C        female free/reduced           0             17             10
#                       standard              29             29             30
#                male   free/reduced          27             28             27
# ...

# %%
std_per.groupby(["race/ethnicity","gender","lunch"])[["math score","reading score","writing score"]].max()
# Out:
#                                     math score  reading score  writing score
# race/ethnicity gender lunch
# group A        female free/reduced          77             88             85
#                       standard              92            100             97
#                male   free/reduced          81             82             82
#                       standard             100             96             92
# group B        female free/reduced          78             97             94
#                       standard              97             97             96
#                male   free/reduced          88             90             88
#                       standard              94             96             92
# group C        female free/reduced          82             93             93
#                       standard              96            100            100
#                male   free/reduced          87             81             82
# ...

# %%
std_per.groupby(["race/ethnicity","gender","lunch"])[["math score","reading score","writing score"]].mean()
# Out:
#                                     math score  reading score  writing score
# race/ethnicity gender lunch
# group A        female free/reduced   49.928571      61.071429      58.285714
#                       standard       64.000000      74.045455      73.954545
#                male   free/reduced   58.590909      60.227273      56.500000
#                       standard       67.387097      62.806452      61.032258
# group B        female free/reduced   56.512821      69.153846      67.230769
#                       standard       64.338462      72.230769      71.738462
#                male   free/reduced   58.633333      57.233333      54.100000
#                       standard       69.839286      65.857143      63.500000
# group C        female free/reduced   52.838710      65.564516      64.080645
#                       standard       66.864407      75.296610      75.822034
#                male   free/reduced   60.673077      60.846154      58.230769
# ...

# %%
std_per.groupby(["race/ethnicity","gender","lunch"])[["math score","reading score","writing score"]].std()
# Out:
#                                     math score  reading score  writing score
# race/ethnicity gender lunch
# group A        female free/reduced   12.079635      13.870080      13.193405
#                       standard       12.769010      13.407451      12.249304
#                male   free/reduced   14.568914      15.246957      15.491165
#                       standard       13.554034      15.755252      14.844716
# group B        female free/reduced   17.027643      16.117232      16.846773
#                       standard       15.160884      13.631041      13.440002
#                male   free/reduced   14.329818      14.528648      15.318121
#                       standard       12.524560      14.001855      13.635515
# group C        female free/reduced   14.931750      14.723262      15.984930
#                       standard       12.648378      12.235097      12.421811
#                male   free/reduced   12.377591      11.702831      10.537729
# ...

# %%
std_per
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
pd.pivot_table(std_per,columns="race/ethnicity",index="gender",values="math score")
# Out:
# race/ethnicity    group A    group B    group C    group D    group E
# gender
# female          58.527778  61.403846  62.033333  65.248062  70.811594
# male            63.735849  65.930233  67.611511  69.413534  76.746479

# %%
pd.pivot_table(std_per,columns="gender",index="race/ethnicity",values="math score")
# Out:
# gender             female       male
# race/ethnicity
# group A         58.527778  63.735849
# group B         61.403846  65.930233
# group C         62.033333  67.611511
# group D         65.248062  69.413534
# group E         70.811594  76.746479

# %%
pd.pivot_table(std_per,columns="parental level of education",index="test preparation course",values="writing score")
# Out:
# parental level of education  associate's degree  bachelor's degree  \
# test preparation course
# completed                             76.817073          78.695652
# none                                  65.842857          69.986111
#
# parental level of education  high school  master's degree  some college  \
# test preparation course
# completed                      68.053571        80.100000     76.519481
# none                           60.207143        73.410256     64.872483
#
# parental level of education  some high school
# test preparation course
# completed                           70.363636
# none                                60.754902

# %%
pd.pivot_table(std_per,columns="parental level of education",index="test preparation course",values="writing score",aggfunc="mean")
# Out:
# parental level of education  associate's degree  bachelor's degree  \
# test preparation course
# completed                             76.817073          78.695652
# none                                  65.842857          69.986111
#
# parental level of education  high school  master's degree  some college  \
# test preparation course
# completed                      68.053571        80.100000     76.519481
# none                           60.207143        73.410256     64.872483
#
# parental level of education  some high school
# test preparation course
# completed                           70.363636
# none                                60.754902

# %%
std_per[std_per["lunch"]=="standard"]
# Out:
#      gender race/ethnicity parental level of education     lunch  \
# 0    female        group B           bachelor's degree  standard
# 1    female        group C                some college  standard
# 2    female        group B             master's degree  standard
# 4      male        group C                some college  standard
# 5    female        group B          associate's degree  standard
# ..      ...            ...                         ...       ...
# 987    male        group E            some high school  standard
# 991  female        group B            some high school  standard
# 994    male        group A                 high school  standard
# 995  female        group E             master's degree  standard
# 998  female        group D                some college  standard
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# ...

# %%
std_per["lunch"]=="standard"
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4       True
#        ...
# 995     True
# 996    False
# 997    False
# 998     True
# 999    False
# Name: lunch, Length: 1000, dtype: bool

# %%
(std_per["lunch"]=="standard")&(std_per["test preparation course"]=="completed")
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 995     True
# 996    False
# 997    False
# 998     True
# 999    False
# Length: 1000, dtype: bool

# %%
std_per["race/ethnicity"].isin(["group A","group D"])
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998     True
# 999     True
# Name: race/ethnicity, Length: 1000, dtype: bool

# %%
std_per[std_per["race/ethnicity"].isin(["group A","group D"])]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 3      male        group A          associate's degree  free/reduced
# 8      male        group D                 high school  free/reduced
# 11     male        group D          associate's degree      standard
# 13     male        group A                some college      standard
# 14   female        group A             master's degree      standard
# ..      ...            ...                         ...           ...
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 994    male        group A                 high school      standard
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
std_per.query("lunch=='standard'")
# Out:
#      gender race/ethnicity parental level of education     lunch  \
# 0    female        group B           bachelor's degree  standard
# 1    female        group C                some college  standard
# 2    female        group B             master's degree  standard
# 4      male        group C                some college  standard
# 5    female        group B          associate's degree  standard
# ..      ...            ...                         ...       ...
# 987    male        group E            some high school  standard
# 991  female        group B            some high school  standard
# 994    male        group A                 high school  standard
# 995  female        group E             master's degree  standard
# 998  female        group D                some college  standard
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# ...

# %%
std_per.query("lunch=='standard'  and  `test preparation course`=='completed'")
# Out:
#      gender race/ethnicity parental level of education     lunch  \
# 1    female        group C                some college  standard
# 6    female        group B                some college  standard
# 13     male        group A                some college  standard
# 35     male        group E          associate's degree  standard
# 46   female        group A          associate's degree  standard
# ..      ...            ...                         ...       ...
# 983  female        group A                some college  standard
# 987    male        group E            some high school  standard
# 991  female        group B            some high school  standard
# 995  female        group E             master's degree  standard
# 998  female        group D                some college  standard
#
#     test preparation course  math score  reading score  writing score
# 1                 completed          69             90             88
# ...

# %%
std_per.query("`math score`.between(50,55)")
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 14   female        group A             master's degree      standard
# 19   female        group C          associate's degree  free/reduced
# 37   female        group D            some high school  free/reduced
# 40     male        group C          associate's degree  free/reduced
# 42   female        group B          associate's degree      standard
# ..      ...            ...                         ...           ...
# 945  female        group C          associate's degree      standard
# 972  female        group A                 high school  free/reduced
# 974  female        group A                some college      standard
# 978    male        group D                 high school      standard
# 992  female        group D          associate's degree  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
std_per.query("`parental level of education`.str.contains('ma')" )
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 2    female        group B             master's degree      standard
# 14   female        group A             master's degree      standard
# 18     male        group C             master's degree  free/reduced
# 25     male        group A             master's degree  free/reduced
# 29   female        group D             master's degree      standard
# 32   female        group E             master's degree  free/reduced
# 79   female        group E             master's degree      standard
# 106  female        group D             master's degree      standard
# 128    male        group D             master's degree      standard
# 130    male        group D             master's degree      standard
# 162    male        group B             master's degree  free/reduced
# 164  female        group E             master's degree      standard
# 167  female        group B             master's degree  free/reduced
# ...

# %%
user=pd.read_excel("Bank Data.xlsx",sheet_name="User_Details")

# %%
loan=pd.read_excel("Bank Data.xlsx",sheet_name="Loan_Details")

# %%
bike=pd.read_excel("Bank Data.xlsx",sheet_name="Bike_Loan")

# %%
car=pd.read_excel("Bank Data.xlsx",sheet_name="Car_Loan")

# %%
home=pd.read_excel("Bank Data.xlsx",sheet_name="Home_Loan")

# %%
pd.merge(user,loan)
# Out:
#     User ID User Name  Loan ID
# 0         1       Ram      101
# 1         1       Ram      201
# 2         1       Ram      301
# 3         2      Sham      202
# 4         2      Sham      302
# 5         3      Sita      102
# 6         3      Sita      203
# 7         3      Sita      303
# 8         4      Gita      103
# 9         5    Suresh      104
# 10        5    Suresh      204
# 11        5    Suresh      304
# 12        6    Ramesh      205
# 13        6    Ramesh      305

# %%
pd.merge(user,loan,left_on="User ID",right_on="User ID",how="inner")
# Out:
#     User ID User Name  Loan ID
# 0         1       Ram      101
# 1         1       Ram      201
# 2         1       Ram      301
# 3         2      Sham      202
# 4         2      Sham      302
# 5         3      Sita      102
# 6         3      Sita      203
# 7         3      Sita      303
# 8         4      Gita      103
# 9         5    Suresh      104
# 10        5    Suresh      204
# 11        5    Suresh      304
# 12        6    Ramesh      205
# 13        6    Ramesh      305

# %%
pd.concat([bike,car,home])
# Out:
#    Loan ID  Amount
# 0      101    1200
# 1      102    3300
# 2      103    2700
# 3      104    2900
# 0      201    3900
# 1      202    1900
# 2      203    2900
# 3      204    3300
# 4      205    2300
# 0      301    6700
# 1      302    6500
# 2      303    5900
# 3      304    6000
# 4      305    6200

# %%
pd.concat([bike,car,home],axis=1)
# Out:
#    Loan ID  Amount  Loan ID  Amount  Loan ID  Amount
# 0    101.0  1200.0      201    3900      301    6700
# 1    102.0  3300.0      202    1900      302    6500
# 2    103.0  2700.0      203    2900      303    5900
# 3    104.0  2900.0      204    3300      304    6000
# 4      NaN     NaN      205    2300      305    6200

# %%
all_loans=pd.concat([bike,car,home])

# %%
all_loans
# Out:
#    Loan ID  Amount
# 0      101    1200
# 1      102    3300
# 2      103    2700
# 3      104    2900
# 0      201    3900
# 1      202    1900
# 2      203    2900
# 3      204    3300
# 4      205    2300
# 0      301    6700
# 1      302    6500
# 2      303    5900
# 3      304    6000
# 4      305    6200

# %%
all_loans.reset_index()
# Out:
#     index  Loan ID  Amount
# 0       0      101    1200
# 1       1      102    3300
# 2       2      103    2700
# 3       3      104    2900
# 4       0      201    3900
# 5       1      202    1900
# 6       2      203    2900
# 7       3      204    3300
# 8       4      205    2300
# 9       0      301    6700
# 10      1      302    6500
# 11      2      303    5900
# 12      3      304    6000
# 13      4      305    6200

# %%
all_loans.reset_index(drop=True)
# Out:
#     Loan ID  Amount
# 0       101    1200
# 1       102    3300
# 2       103    2700
# 3       104    2900
# 4       201    3900
# 5       202    1900
# 6       203    2900
# 7       204    3300
# 8       205    2300
# 9       301    6700
# 10      302    6500
# 11      303    5900
# 12      304    6000
# 13      305    6200

# %%
all_loans.reset_index(drop=True,inplace=True)

# %%
all_loans
# Out:
#     Loan ID  Amount
# 0       101    1200
# 1       102    3300
# 2       103    2700
# 3       104    2900
# 4       201    3900
# 5       202    1900
# 6       203    2900
# 7       204    3300
# 8       205    2300
# 9       301    6700
# 10      302    6500
# 11      303    5900
# 12      304    6000
# 13      305    6200

# %%
std_per
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
std_per.drop("test preparation course",axis=1)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#      math score  reading score  writing score
# 0            72             72             74
# ...

# %%
std_per.drop("test preparation course",axis=1,inplace=True)

# %%
std_per
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#      math score  reading score  writing score
# 0            72             72             74
# ...
