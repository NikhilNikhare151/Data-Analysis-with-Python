# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import warnings 
warnings.filterwarnings("ignore")

# %%
list_of_orders=pd.read_excel("Amazing Mart.xlsx",sheet_name="ListOfOrders")
orders_breakdown=pd.read_excel("Amazing Mart.xlsx",sheet_name="OrderBreakdown")

# %%
list_of_orders
# Out:
#              Order ID Order Date        Customer Name        City  \
# 0     BN-2011-7407039 2011-01-01           Ruby Patel   Stockholm
# 1     AZ-2011-9050313 2011-01-03       Summer Hayward   Southport
# 2     AZ-2011-6674300 2011-01-04     Devin Huddleston     Valence
# 3     BN-2011-2819714 2011-01-04          Mary Parker  Birmingham
# 4      AZ-2011-617423 2011-01-05         Daniel Burke  Echirolles
# ...               ...        ...                  ...         ...
# 4112  AZ-2014-8174835 2014-12-31         Eloise Sykes   Bielefeld
# 4113   AZ-2014-766953 2014-12-31         Jose Gambino  Maidenhead
# 4114  AZ-2014-1412225 2014-12-31          Leon Barnes   Worcester
# 4115  AZ-2014-7604524 2014-12-31  Rebecca Chamberlain     Hamburg
# 4116  BN-2014-4140795 2014-12-31      Daniel Hamilton   Eindhoven
#
#              Country   Region      Segment  Ship Date     Ship Mode  \
# 0             Sweden    North  Home Office 2011-01-05  Economy Plus
# ...

# %%
orders_breakdown
# Out:
#              Order ID                           Product Name  Discount  Sales  \
# 0     BN-2011-7407039            Enermax Note Cards, Premium       0.5     45
# 1     AZ-2011-9050313     Dania Corner Shelving, Traditional       0.0    854
# 2     AZ-2011-6674300  Binney & Smith Sketch Pad, Easy-Erase       0.0    140
# 3     BN-2011-2819714             Boston Markers, Easy-Erase       0.5     27
# 4     BN-2011-2819714            Eldon Folders, Single Width       0.5     17
# ...               ...                                    ...       ...    ...
# 8042   AZ-2014-766953   Ikea Stackable Bookrack, Traditional       0.0    245
# 8043  BN-2014-4140795      BIC Pencil Sharpener, Fluorescent       0.5     30
# 8044  BN-2014-4140795          Avery Binder Covers, Recycled       0.5     23
# 8045  BN-2014-4140795                    StarTech Phone, Red       0.5    108
# 8046   AZ-2014-766953              Motorola Audio Dock, VoIP       0.0    867
#
# ...

# %%
list_of_orders.head(3)
# Out:
#           Order ID Order Date     Customer Name       City         Country  \
# 0  BN-2011-7407039 2011-01-01        Ruby Patel  Stockholm          Sweden
# 1  AZ-2011-9050313 2011-01-03    Summer Hayward  Southport  United Kingdom
# 2  AZ-2011-6674300 2011-01-04  Devin Huddleston    Valence          France
#
#     Region      Segment  Ship Date     Ship Mode                 State  \
# 0    North  Home Office 2011-01-05  Economy Plus             Stockholm
# 1    North     Consumer 2011-01-07       Economy               England
# 2  Central     Consumer 2011-01-08       Economy  Auvergne-Rhône-Alpes
#
#          lon        lat
# 0  18.068581  59.329324
# 1  -3.010113  53.645708
# 2   4.892360  44.933393

# %%
orders_breakdown.head(3)
# Out:
#           Order ID                           Product Name  Discount  Sales  \
# 0  BN-2011-7407039            Enermax Note Cards, Premium       0.5     45
# 1  AZ-2011-9050313     Dania Corner Shelving, Traditional       0.0    854
# 2  AZ-2011-6674300  Binney & Smith Sketch Pad, Easy-Erase       0.0    140
#
#    Profit  Quantity         Category Sub-Category
# 0     -26         3  Office Supplies        Paper
# 1     290         7        Furniture    Bookcases
# 2      21         3  Office Supplies          Art

# %%
df=pd.merge(list_of_orders,orders_breakdown)
# Out:
# The history saving thread hit an unexpected error (OperationalError('database or disk is full')).History will not be written to the database.

# %%
df.head(3)
# Out:
#           Order ID Order Date     Customer Name       City         Country  \
# 0  BN-2011-7407039 2011-01-01        Ruby Patel  Stockholm          Sweden
# 1  AZ-2011-9050313 2011-01-03    Summer Hayward  Southport  United Kingdom
# 2  AZ-2011-6674300 2011-01-04  Devin Huddleston    Valence          France
#
#     Region      Segment  Ship Date     Ship Mode                 State  \
# 0    North  Home Office 2011-01-05  Economy Plus             Stockholm
# 1    North     Consumer 2011-01-07       Economy               England
# 2  Central     Consumer 2011-01-08       Economy  Auvergne-Rhône-Alpes
#
#          lon        lat                           Product Name  Discount  \
# 0  18.068581  59.329324            Enermax Note Cards, Premium       0.5
# 1  -3.010113  53.645708     Dania Corner Shelving, Traditional       0.0
# 2   4.892360  44.933393  Binney & Smith Sketch Pad, Easy-Erase       0.0
#
#    Sales  Profit  Quantity         Category Sub-Category
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8047 entries, 0 to 8046
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       8047 non-null   object
#  1   Order Date     8047 non-null   datetime64[ns]
#  2   Customer Name  8047 non-null   object
#  3   City           8047 non-null   object
#  4   Country        8047 non-null   object
#  5   Region         8047 non-null   object
#  6   Segment        8047 non-null   object
#  7   Ship Date      8047 non-null   datetime64[ns]
#  8   Ship Mode      8047 non-null   object
#  9   State          8047 non-null   object
#  10  lon            8047 non-null   float64
#  11  lat            8047 non-null   float64
#  12  Product Name   8047 non-null   object
#  13  Discount       8047 non-null   float64
#  14  Sales          8047 non-null   int64
#  15  Profit         8047 non-null   int64
#  16  Quantity       8047 non-null   int64
# ...

# %%
df.isna().sum()
# Out:
# Order ID         0
# Order Date       0
# Customer Name    0
# City             0
# Country          0
# Region           0
# Segment          0
# Ship Date        0
# Ship Mode        0
# State            0
# lon              0
# lat              0
# Product Name     0
# Discount         0
# Sales            0
# Profit           0
# Quantity         0
# Category         0
# Sub-Category     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(2)

# %%
df.drop_duplicates(inplace=True)

# %%
plt.plot(df["Order Date"],df["Sales"])

# %%
plt.figure(figsize=(13,4))
plt.plot(df["Order Date"],df["Sales"])
plt.title("Sales by Dates")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.show()

# %%
df["Year-Month"]=df["Order Date"].dt.to_period("M")

# %%
df
# Out:
#              Order ID Order Date        Customer Name        City  \
# 0     BN-2011-7407039 2011-01-01           Ruby Patel   Stockholm
# 1     AZ-2011-9050313 2011-01-03       Summer Hayward   Southport
# 2     AZ-2011-6674300 2011-01-04     Devin Huddleston     Valence
# 3     BN-2011-2819714 2011-01-04          Mary Parker  Birmingham
# 4     BN-2011-2819714 2011-01-04          Mary Parker  Birmingham
# ...               ...        ...                  ...         ...
# 8042  AZ-2014-1412225 2014-12-31          Leon Barnes   Worcester
# 8043  AZ-2014-7604524 2014-12-31  Rebecca Chamberlain     Hamburg
# 8044  BN-2014-4140795 2014-12-31      Daniel Hamilton   Eindhoven
# 8045  BN-2014-4140795 2014-12-31      Daniel Hamilton   Eindhoven
# 8046  BN-2014-4140795 2014-12-31      Daniel Hamilton   Eindhoven
#
#              Country   Region      Segment  Ship Date     Ship Mode  \
# 0             Sweden    North  Home Office 2011-01-05  Economy Plus
# ...

# %%
df["Year-Month"].head()
# Out:
# 0    2011-01
# 1    2011-01
# 2    2011-01
# 3    2011-01
# 4    2011-01
# Name: Year-Month, dtype: period[M]

# %%
df.groupby("Year-Month")["Sales"].sum()
# Out:
# Year-Month
# 2011-01     14335
# 2011-02     21646
# 2011-03     20567
# 2011-04     21920
# 2011-05     28955
# 2011-06     48837
# 2011-07     16635
# 2011-08     47822
# 2011-09     62455
# 2011-10     15670
# 2011-11     52567
# 2011-12     62939
# 2012-01     30022
# 2012-02     15304
# 2012-03     41388
# 2012-04     30771
# 2012-05     34359
# 2012-06     54760
# 2012-07     38345
# 2012-08     85074
# 2012-09     61777
# 2012-10     35686
# 2012-11     55079
# 2012-12     66278
# 2013-01     45698
# 2013-02     47151
# 2013-03     28876
# 2013-04     30627
# 2013-05     41260
# 2013-06     86822
# 2013-07     48720
# 2013-08     63124
# 2013-09     69732
# 2013-10     29938
# 2013-11     77746
# 2013-12     60446
# 2014-01     49102
# 2014-02     39584
# 2014-03     32044
# 2014-04     48733
# 2014-05     37887
# 2014-06     81325
# 2014-07     42459
# 2014-08    107069
# 2014-09    101325
# 2014-10     40567
# 2014-11     91847
# 2014-12     83088
# ...

# %%
monthly_sales=df.groupby("Year-Month")["Sales"].sum().reset_index()

# %%
monthly_sales
# Out:
#    Year-Month   Sales
# 0     2011-01   14335
# 1     2011-02   21646
# 2     2011-03   20567
# 3     2011-04   21920
# 4     2011-05   28955
# 5     2011-06   48837
# 6     2011-07   16635
# 7     2011-08   47822
# 8     2011-09   62455
# 9     2011-10   15670
# 10    2011-11   52567
# 11    2011-12   62939
# 12    2012-01   30022
# 13    2012-02   15304
# 14    2012-03   41388
# 15    2012-04   30771
# 16    2012-05   34359
# 17    2012-06   54760
# 18    2012-07   38345
# 19    2012-08   85074
# 20    2012-09   61777
# 21    2012-10   35686
# 22    2012-11   55079
# 23    2012-12   66278
# 24    2013-01   45698
# 25    2013-02   47151
# 26    2013-03   28876
# 27    2013-04   30627
# 28    2013-05   41260
# 29    2013-06   86822
# 30    2013-07   48720
# 31    2013-08   63124
# 32    2013-09   69732
# 33    2013-10   29938
# 34    2013-11   77746
# 35    2013-12   60446
# 36    2014-01   49102
# 37    2014-02   39584
# 38    2014-03   32044
# 39    2014-04   48733
# ...

# %%
plt.figure(figsize=(13,4))
plt.plot(monthly_sales["Year-Month"].astype(str),monthly_sales["Sales"])
plt.title("Sales by Dates")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.show()

# %%
plt.figure(figsize=(13,4))
plt.plot(monthly_sales["Year-Month"].astype(str),monthly_sales["Sales"])
plt.title("Sales by Dates")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(15,4))
plt.plot(monthly_sales["Year-Month"].astype(str),monthly_sales["Sales"])
plt.title("Sales by Dates")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,4))
plt.plot(monthly_sales["Year-Month"].astype(str),monthly_sales["Sales"])
plt.title("Sales by Dates")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.grid()
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,4))
plt.plot(monthly_sales["Year-Month"].astype(str),monthly_sales["Sales"])
plt.title("Sales by Dates")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.grid(axis="y")
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,4))
plt.plot(monthly_sales["Year-Month"].astype(str),monthly_sales["Sales"],marker="*",markerfacecolor="red")
plt.title("Sales by Dates")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.grid(axis="y")
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,4))
plt.plot(monthly_sales["Year-Month"].astype(str),monthly_sales["Sales"],marker="+",markerfacecolor="red")
plt.title("Sales by Dates")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.grid(axis="y")
plt.xticks(rotation=90)
plt.show()

# %%
monthly_profit=df.groupby("Year-Month")["Profit"].sum().reset_index()

# %%
monthly_profit
# Out:
#    Year-Month  Profit
# 0     2011-01     249
# 1     2011-02     800
# 2     2011-03    4042
# 3     2011-04    3357
# 4     2011-05    1589
# 5     2011-06    5945
# 6     2011-07    2060
# 7     2011-08    6172
# 8     2011-09   11926
# 9     2011-10    1918
# 10    2011-11    7199
# 11    2011-12    9230
# 12    2012-01    2071
# 13    2012-02    4210
# 14    2012-03    2444
# 15    2012-04    1008
# 16    2012-05    5084
# 17    2012-06    9696
# 18    2012-07    6686
# 19    2012-08   15629
# 20    2012-09    4892
# 21    2012-10    4874
# 22    2012-11    1267
# 23    2012-12    8352
# 24    2013-01    7503
# 25    2013-02    7398
# 26    2013-03    2162
# 27    2013-04    4482
# 28    2013-05    3852
# 29    2013-06    8310
# 30    2013-07    5893
# 31    2013-08    6254
# 32    2013-09    7183
# 33    2013-10    5186
# 34    2013-11   11630
# 35    2013-12    7319
# 36    2014-01    7684
# 37    2014-02    2074
# 38    2014-03    4282
# 39    2014-04    7157
# ...

# %%
plt.figure(figsize=(15,4))
plt.plot(monthly_profit["Year-Month"].astype(str),monthly_sales["Profit"],marker="+",markerfacecolor="red")
plt.title("Profit by Dates")
plt.xlabel("Date")
plt.ylabel("Profit")
plt.grid(axis="y")
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,4))
plt.plot(monthly_sales["Year-Month"].astype(str),monthly_sales["Sales"],marker="o",markerfacecolor="red")
plt.plot(monthly_profit["Year-Month"].astype(str),monthly_profit["Profit"],marker="o",markerfacecolor="red")
plt.title("Profit by Dates")
plt.xlabel("Date")
plt.ylabel("Profit")
plt.grid(axis="y")
plt.xticks(rotation=90)
plt.show()

# %%
region_sales=df.groupby("Region")["Sales"].sum().reset_index()
region_sales
# Out:
#     Region    Sales
# 0  Central  1315216
# 1    North   515979
# 2    South   517166

# %%
region_sales_profit=df.groupby("Region")[["Sales","Profit"]].sum().reset_index()
region_sales_profit
# Out:
#     Region    Sales  Profit
# 0  Central  1315216  157626
# 1    North   515979   71439
# 2    South   517166   54137

# %%
plt.pie(region_sales_profit["Sales"])
plt.show()

# %%
plt.pie(region_sales_profit["Sales"],labels=region_sales_profit["Region"])
plt.show()

# %%
plt.pie(region_sales_profit["Sales"],labels=region_sales_profit["Region"],autopct="%.2f%%")
plt.show()

# %%
plt.pie(region_sales_profit["Sales"],labels=region_sales_profit["Region"],autopct="%.2f%%",explode=[0,0.1,0])
plt.show()

# %%
plt.pie(region_sales_profit["Sales"],labels=region_sales_profit["Region"],autopct="%.2f%%",explode=[0.1,0,0])
plt.show()

# %%
plt.pie(region_sales_profit["Sales"],labels=region_sales_profit["Region"],autopct="%.2f%%",explode=[0,0,0.1])
plt.show()

# %%
plt.pie(region_sales_profit["Sales"],labels=region_sales_profit["Region"],autopct="%.2f%%",explode=[0,0,0.05])
plt.show()

# %%
plt.title("Sales by Region")
plt.pie(region_sales_profit["Sales"],labels=region_sales_profit["Region"],autopct="%.2f%%",explode=[0,0,0.1])
plt.show()

# %%
plt.title("Sales by Region")
plt.pie(region_sales_profit["Sales"],labels=region_sales_profit["Region"],autopct="%.2f%%",explode=[0,0,0.1],colors=["#DE3163","#FF7F50","#FFBF00"])
plt.show()

# %%
plt.figure(figsize=(15,4))

plt.subplot(1,2,1)
plt.title("Sales by Region")
plt.pie(region_sales_profit["Sales"],labels=region_sales_profit["Region"],autopct="%.2f%%",explode=[0,0,0.1],colors=["#DE3163","#FF7F50","#FFBF00"])

plt.subplot(1,2,2)
plt.title("Profit by Region")
plt.pie(region_sales_profit["Sales"],labels=region_sales_profit["Region"],autopct="%.2f%%",explode=[0,0,0.1],colors=["#DE3163","#FF7F50","#FFBF00"])

plt.show()

# %%
subcategory_sales_profit= df.groupby("Sub-Category")[["Sales","Profit"]].sum().reset_index()
subcategory_sales_profit
# Out:
#    Sub-Category   Sales  Profit
# 0   Accessories  131309   26830
# 1    Appliances  209900   37906
# 2           Art  127147   23481
# 3       Binders   78850   14675
# 4     Bookcases  294396   43655
# 5        Chairs  186698   15489
# 6       Copiers  290081   42775
# 7     Envelopes   31210    6463
# 8     Fasteners   16238    3420
# 9   Furnishings   68237   11321
# 10       Labels   12822    2636
# 11     Machines  182066   11318
# 12        Paper   36057    7485
# 13       Phones  282559   27631
# 14      Storage  272489   21995
# 15     Supplies   38824    6853
# 16       Tables   89478  -20731

# %%
plt.barh(subcategory_sales_profit["Sub-Category"],subcategory_sales_profit["Sales"])
plt.show()

# %%
plt.barh(subcategory_sales_profit["Sub-Category"],subcategory_sales_profit["Sales"],color="darkred")
plt.title("Sales by Sub-Category")
plt.xlabel("Sales")
plt.grid(axis="x")
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.barh(subcategory_sales_profit["Sub-Category"],subcategory_sales_profit["Sales"],color="darkred")
plt.title("Sales by Sub-Category")
plt.xlabel("Sales")
plt.grid(axis="x")
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.barh(subcategory_sales_profit["Sub-Category"],subcategory_sales_profit["Sales"])
plt.barh(subcategory_sales_profit["Sub-Category"],subcategory_sales_profit["Profit"],left=subcategory_sales_profit["Sales"])
plt.title("Sales by Sub-Category")
plt.xlabel("Sales")
plt.grid(axis="x")
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.barh(subcategory_sales_profit["Sub-Category"],subcategory_sales_profit["Sales"],label="Sales")
plt.barh(subcategory_sales_profit["Sub-Category"],subcategory_sales_profit["Profit"],label="Profit",left=subcategory_sales_profit["Sales"])
plt.title("Sales by Sub-Category")
plt.xlabel("Sales")
plt.legend()
plt.grid(axis="x")
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.barh(subcategory_sales_profit["Sub-Category"],subcategory_sales_profit["Sales"],label="Sales")
plt.barh(subcategory_sales_profit["Sub-Category"],subcategory_sales_profit["Profit"],label="Profit",left=subcategory_sales_profit["Sales"],height=0.3)
plt.title("Sales & Profit by Sub-Category")
plt.xlabel("Sales & Profit")
plt.legend()
plt.grid(axis="x")
plt.show()

# %%
plt.figure(figsize=(14,5))
plt.scatter(df["Sales"],df["Profit"],alpha=0.5,edgecolors="darkblue")
plt.xlabel("Sales")
plt.ylabel("Profit")
plt.title("Sales vs Profit")
plt.grid()
plt.show()

# %%
plt.figure(figsize=(14,5))
plt.scatter(df["Sales"],df["Profit"],alpha=0.5,edgecolors="darkblue",s=df["Quantity"]*10)
plt.xlabel("Sales")
plt.ylabel("Profit")
plt.title("Sales vs Profit")
plt.grid()
plt.show()

# %%
plt.figure(figsize=(14,5))
plt.scatter(df["Sales"],df["Profit"],alpha=0.7,edgecolors="darkblue",c=df["Quantity"],s=df["Quantity"]*15)
plt.xlabel("Sales")
plt.ylabel("Profit")
plt.title("Sales vs Profit")
plt.colorbar()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(14,5))
plt.scatter(df["Sales"],df["Profit"],alpha=0.7,edgecolors="darkblue",c=df["Quantity"],s=df["Quantity"]*15,cmap="plasma")
plt.xlabel("Sales")
plt.ylabel("Profit")
plt.title("Sales vs Profit")
plt.colorbar()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(14,5))
plt.scatter(df["Sales"],df["Profit"],alpha=0.7,edgecolors="darkblue",c=df["Quantity"],s=df["Quantity"]*15,cmap="Blues")
plt.xlabel("Sales")
plt.ylabel("Profit")
plt.title("Sales vs Profit")
plt.colorbar()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(14,5))
plt.scatter(df["Sales"],df["Profit"],alpha=0.7,edgecolors="black",c=df["Quantity"],s=df["Quantity"]*15,cmap="Reds")
plt.xlabel("Sales")
plt.ylabel("Profit")
plt.title("Sales vs Profit")
plt.colorbar()
plt.grid()
plt.show()
